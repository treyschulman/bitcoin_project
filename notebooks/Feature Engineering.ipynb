# %% [markdown]
# # Feature Engineering Notebook
# - loads in fully cleaned data with target already constructed
# - engineers features and final dataset for model training, selection, and evaluation

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/bitcoin_clean.csv", parse_dates=["Date"])
df = df.sort_values("Date").reset_index(drop=True)

# %%
def make_lags(df_in, col, lags):
    """Helper function to create lag columns"""
    out = df_in.copy()
    for lag in lags:
        out[f"{col}_lag{lag}"] = out[col].shift(lag)
    return out

def make_rolls(df_in, col, windows_mean=(3,7,14,30), windows_std=(7,14,30)):
    """Helper function to create rolling statistics"""
    out = df_in.copy()
    for w in windows_mean:
        out[f"{col}_ma{w}"] = out[col].rolling(window=w, min_periods=w).mean()
    for w in windows_std:
        out[f"{col}_std{w}"] = out[col].rolling(window=w, min_periods=w).std()
    return out

# %%
# lags and rolling stats for price
df = make_lags(df, "btc_market_price", lags=[1,7,14,30])
df = make_rolls(df, "btc_market_price", windows_mean=(7,14,30), windows_std=(7,14,30))

# %%
# add day of week and month cols then dummify
df["dow"] = df["Date"].dt.dayofweek
df["month"] = df["Date"].dt.month
df = pd.get_dummies(df, columns=["dow", "month"], drop_first=True)

# %%
# log transform heavy tailed fields
log_cols = [
    "btc_trade_volume",
    "btc_transaction_fees",
    "btc_output_volume",
    "btc_estimated_transaction_volume"
]
for col in log_cols:
    if col in df.columns:
        df[col + "_log"] = np.log1p(df[col])

df = df.dropna().reset_index(drop=True)

# %%
df.to_csv("../data/bitcoin_features.csv", index=False)

df.head(10)
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_trade_volume  \
# 0 2010-09-16          0.061900           4005400.0           43.8000
# 1 2010-09-17          0.060900           4016200.0          435.7200
# 2 2010-09-18          0.060900           4028050.0          425.5566
# 3 2010-09-19          0.062599           4038550.0          771.1302
# 4 2010-09-20          0.063400           4049100.0          858.4764
# 5 2010-09-21          0.063300           4057950.0          344.1570
# 6 2010-09-22          0.062800           4066600.0          693.6240
# 7 2010-09-23          0.063000           4077200.0          930.3198
# 8 2010-09-24          0.062810           4089500.0           41.0628
# 9 2010-09-25          0.062400           4099600.0          129.1500
#
#    btc_avg_block_size  btc_median_confirmation_time  btc_hash_rate  \
# 0            0.000549                           0.0       0.006733
# 1            0.000439                           0.0       0.007655
# 2            0.000740                           0.0       0.008399
# 3            0.000484                           0.0       0.009581
# 4            0.000583                           0.0       0.009627
# 5            0.001130                           0.0       0.008076
# 6            0.001543                           0.0       0.007893
# 7            0.001009                           0.0       0.009673
# 8            0.000651                           0.0       0.011224
# 9            0.000635                           0.0       0.009216
#
#    btc_transaction_fees  btc_cost_per_transaction  btc_n_unique_addresses  \
# 0          0.000000e+00                  1.547500                   385.0
# 1          0.000000e+00                  1.735409                   382.0
# 2          1.800000e-01                  1.674397                   445.0
# 3          0.000000e+00                  1.938907                   379.0
# 4          0.000000e+00                  1.585000                   469.0
# 5          1.000000e-07                  0.880825                   743.0
# 6          0.000000e+00                  0.679875                   999.0
# 7          0.000000e+00                  0.956734                   801.0
# 8          0.000000e+00                  1.384522                   631.0
# 9          0.000000e+00                  1.397428                   499.0
#
#    btc_n_transactions  btc_output_volume  btc_estimated_transaction_volume  \
# 0               380.0       39173.550000                           20542.0
# 1               379.0       44589.060000                           29419.0
# 2               431.0       81783.000000                           64511.0
# 3               339.0       63683.909603                           47333.0
# 4               422.0       71345.620000                           37079.0
# 5               636.0       39944.080000                           19532.0
# 6               799.0       51528.040000                           29221.0
# 7               698.0      123082.780000                           52468.0
# 8               558.0       48867.600000                           33287.0
# 9               451.0       32462.930000                           17081.0
#
#    target_t7  btc_market_price_lag1  btc_market_price_lag7  \
# 0   0.063000               0.175000               0.062400
# 1   0.062810               0.061900               0.062010
# 2   0.062400               0.060900               0.062000
# 3   0.062279               0.060900               0.064999
# 4   0.062206               0.062599               0.062010
# 5   0.062710               0.063400               0.064100
# 6   0.062190               0.063300               0.175000
# 7   0.061920               0.062800               0.061900
# 8   0.061999               0.063000               0.060900
# 9   0.061999               0.062810               0.060900
#
#    btc_market_price_lag14  btc_market_price_lag30  btc_market_price_ma7  \
# 0                 0.06290                0.076900              0.078860
# 1                 0.06340                0.074000              0.078701
# 2                 0.06130                0.068800              0.078544
# 3                 0.06290                0.066700              0.078201
# 4                 0.06400                0.066899              0.078400
# 5                 0.06185                0.066400              0.078286
# 6                 0.06201                0.066000              0.062257
# 7                 0.06240                0.066889              0.062414
# 8                 0.06201                0.066500              0.062687
# 9                 0.06200                0.066499              0.062901
#
#    btc_market_price_ma14  btc_market_price_ma30  btc_market_price_std7  \
# 0               0.070706               0.068505               0.042412
# 1               0.070527               0.068068               0.042487
# 2               0.070499               0.067805               0.042561
# 3               0.070477               0.067668               0.042698
# 4               0.070434               0.067551               0.042614
# 5               0.070538               0.067448               0.042659
# 6               0.070594               0.067341               0.001050
# 7               0.070637               0.067212               0.001070
# 8               0.070694               0.067089               0.000838
# 9               0.070723               0.066952               0.000360
#
#    btc_market_price_std14  btc_market_price_std30  dow_1  dow_2  dow_3  dow_4  \
# 0                0.030037                0.020299  False  False   True  False
# 1                0.030091                0.020318  False  False  False   True
# 2                0.030101                0.020359  False  False  False  False
# 3                0.030107                0.020380  False  False  False  False
# 4                0.030117                0.020395  False  False  False  False
# 5                0.030088                0.020409   True  False  False  False
# 6                0.030071                0.020425  False   True  False  False
# 7                0.030059                0.020440  False  False   True  False
# 8                0.030042                0.020456  False  False  False   True
# 9                0.030033                0.020474  False  False  False  False
#
#    dow_5  dow_6  month_2  month_3  month_4  month_5  month_6  month_7  \
# 0  False  False    False    False    False    False    False    False
# 1  False  False    False    False    False    False    False    False
# 2   True  False    False    False    False    False    False    False
# 3  False   True    False    False    False    False    False    False
# 4  False  False    False    False    False    False    False    False
# 5  False  False    False    False    False    False    False    False
# 6  False  False    False    False    False    False    False    False
# 7  False  False    False    False    False    False    False    False
# 8  False  False    False    False    False    False    False    False
# 9   True  False    False    False    False    False    False    False
#
#    month_8  month_9  month_10  month_11  month_12  btc_trade_volume_log  \
# 0    False     True     False     False     False              3.802208
# 1    False     True     False     False     False              6.079292
# 2    False     True     False     False     False              6.055745
# 3    False     True     False     False     False              6.649153
# 4    False     True     False     False     False              6.756323
# 5    False     True     False     False     False              5.843999
# 6    False     True     False     False     False              6.543371
# 7    False     True     False     False     False              6.836603
# 8    False     True     False     False     False              3.739164
# 9    False     True     False     False     False              4.868688
#
#    btc_transaction_fees_log  btc_output_volume_log  \
# 0              0.000000e+00              10.575783
# 1              0.000000e+00              10.705266
# 2              1.655144e-01              11.311837
# 3              0.000000e+00              11.061703
# 4              0.000000e+00              11.175305
# 5              1.000000e-07              10.595261
# 6              0.000000e+00              10.849901
# 7              0.000000e+00              11.720621
# 8              0.000000e+00              10.796890
# 9              0.000000e+00              10.387885
#
#    btc_estimated_transaction_volume_log
# 0                              9.930276
# 1                             10.289430
# 2                             11.074607
# 3                             10.764984
# 4                             10.520833
# 5                              9.879861
# 6                             10.282677
# 7                             10.867978
# 8                             10.412952
# 9                              9.745781

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2708 entries, 0 to 2707
# Data columns (total 45 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  2708 non-null   datetime64[ns]
#  1   btc_market_price                      2708 non-null   float64
#  2   btc_total_bitcoins                    2708 non-null   float64
#  3   btc_trade_volume                      2708 non-null   float64
#  4   btc_avg_block_size                    2708 non-null   float64
#  5   btc_median_confirmation_time          2708 non-null   float64
#  6   btc_hash_rate                         2708 non-null   float64
#  7   btc_transaction_fees                  2708 non-null   float64
#  8   btc_cost_per_transaction              2708 non-null   float64
#  9   btc_n_unique_addresses                2708 non-null   float64
#  10  btc_n_transactions                    2708 non-null   float64
#  11  btc_output_volume                     2708 non-null   float64
#  12  btc_estimated_transaction_volume      2708 non-null   float64
#  13  target_t7                             2708 non-null   float64
#  14  btc_market_price_lag1                 2708 non-null   float64
#  15  btc_market_price_lag7                 2708 non-null   float64
#  16  btc_market_price_lag14                2708 non-null   float64
#  17  btc_market_price_lag30                2708 non-null   float64
#  18  btc_market_price_ma7                  2708 non-null   float64
#  19  btc_market_price_ma14                 2708 non-null   float64
#  20  btc_market_price_ma30                 2708 non-null   float64
#  21  btc_market_price_std7                 2708 non-null   float64
#  22  btc_market_price_std14                2708 non-null   float64
#  23  btc_market_price_std30                2708 non-null   float64
#  24  dow_1                                 2708 non-null   bool
#  25  dow_2                                 2708 non-null   bool
#  26  dow_3                                 2708 non-null   bool
#  27  dow_4                                 2708 non-null   bool
#  28  dow_5                                 2708 non-null   bool
#  29  dow_6                                 2708 non-null   bool
#  30  month_2                               2708 non-null   bool
#  31  month_3                               2708 non-null   bool
#  32  month_4                               2708 non-null   bool
#  33  month_5                               2708 non-null   bool
#  34  month_6                               2708 non-null   bool
#  35  month_7                               2708 non-null   bool
#  36  month_8                               2708 non-null   bool
#  37  month_9                               2708 non-null   bool
#  38  month_10                              2708 non-null   bool
#  39  month_11                              2708 non-null   bool
#  40  month_12                              2708 non-null   bool
#  41  btc_trade_volume_log                  2708 non-null   float64
#  42  btc_transaction_fees_log              2708 non-null   float64
#  43  btc_output_volume_log                 2708 non-null   float64
#  44  btc_estimated_transaction_volume_log  2708 non-null   float64
# dtypes: bool(17), datetime64[ns](1), float64(27)
# memory usage: 637.5 KB
